# %% [markdown]
# <a href="https://colab.research.google.com/github/sara510singh-acc/GenAI-portfolio/blob/main/case_study1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path='/content/drive/MyDrive/gen_ai material/asian_paints.txt'

# %%
with open(file_path, 'r') as file:
  content=file.read()

# %%
content
# Out:
# "\ufeffAPL/SEC/57/2025-26/26 \n \n2nd February 2026 \n \nBSE Limited National Stock Exchange of India Limited \nPhiroze Jeejeebhoy Towers, Exchange Plaza, C-1, Block G, \nDalal Street, Bandra Kurla Complex, Bandra (East), \nMumbai – 400 001 Mumbai – 400 051  \nSecurity Code: 500820 Symbol: ASIANPAINT \n\nSir/Madam, \n \nSub: Intimation under Regulation 30 of the SEBI (Listing Obligations and Disclosure \n\nRequirements) Regulations, 2015 – Transcript of the Investor Conference  \n \nPursuant to Regulation 30 of the Securities and Exchange Board of India (Listing Obligations \nand Disclosure Requirements) Regulations, 2015, please find enclosed the transcript of the \nInvestor Conference held on Tuesday, 27th January 2026, with regard to the business and \nfinancial performance of the Company for the quarter and nine months period ended                        \n31st December 2025. \n \nThe transcript has also been uploaded on the Company’s website and can be accessed \nthrough the fol
# ...

# %%
print(content)
# Out:
# ﻿APL/SEC/57/2025-26/26
#
# 2nd February 2026
#
# BSE Limited National Stock Exchange of India Limited
# Phiroze Jeejeebhoy Towers, Exchange Plaza, C-1, Block G,
# Dalal Street, Bandra Kurla Complex, Bandra (East),
# Mumbai – 400 001 Mumbai – 400 051
# Security Code: 500820 Symbol: ASIANPAINT
#
# Sir/Madam,
#
# Sub: Intimation under Regulation 30 of the SEBI (Listing Obligations and Disclosure
#
# Requirements) Regulations, 2015 – Transcript of the Investor Conference
#
# Pursuant to Regulation 30 of the Securities and Exchange Board of India (Listing Obligations
# and Disclosure Requirements) Regulations, 2015, please find enclosed the transcript of the
# Investor Conference held on Tuesday, 27th January 2026, with regard to the business and
# financial performance of the Company for the quarter and nine months period ended
# 31st December 2025.
#
# The transcript has also been uploaded on the Company’s website and can be accessed
# through the following link:
#
# ...

# %%
len(content)
# Out:
# 54953

# %%
base_instruction='''You are a helpful assistant which helps  financial analysts retrieve the relevant financial information
and business related information from the documents I provide as input.
Give below are some questions and the transcripts of an earning call of a paints company, Asian Paints which was
attended by the top managementof the firm.
Try to respond with specific numbers and facts wherever it is possible.
If you are unsure about any of the question given to you simply say that you dont know about that.''' #system prompt

# %%
question='how much asian paints business has grown?' #user role

# %%
prompt= base_instruction + "\n\n" + "Question:{0}".format(question) + "\n\n" + "Transcript: \n {0}".format(content)

# %%
print(prompt)
# Out:
# You are a helpful assistant which helps  financial analysts retrieve the relevant financial information
# and business related information from the documents I provide as input.
# Give below are some questions and the transcripts of an earning call of a paints company, Asian Paints which was
# attended by the top managementof the firm.
# Try to respond with specific numbers and facts wherever it is possible.
# If you are unsure about any of the question given to you simply say that you dont know about that.
#
# Question:how much asian paints business has grown?
#
# Transcript:
#  ﻿APL/SEC/57/2025-26/26
#
# 2nd February 2026
#
# BSE Limited National Stock Exchange of India Limited
# Phiroze Jeejeebhoy Towers, Exchange Plaza, C-1, Block G,
# Dalal Street, Bandra Kurla Complex, Bandra (East),
# Mumbai – 400 001 Mumbai – 400 051
# Security Code: 500820 Symbol: ASIANPAINT
#
# Sir/Madam,
#
# Sub: Intimation under Regulation 30 of the SEBI (Listing Obligations and Disclosure
#
# ...

# %%
message = [{"role":"user","content":prompt}]

# %%
message
# Out:
# [{'role': 'user',
# ...

# %%
# !pip install openAI

# %%
import openai

# %%
openai.api_key="sk-********************************************************************************************************************************"

# %%
chat_response = openai.chat.completions.create(
    model="gpt-3.5-turbo-16k",
    messages=message,
    max_tokens=1000,
    temperature=0.5,
    n=1,
    stop=None,
    frequency_penalty=0,
    presence_penalty=0)
print(chat_response.choices[0].message.content)
# Out:
# I am sorry, but I do not have the specific information about which company Asian Paints acquired based on the transcript provided. The earnings call focused more on the company's performance and strategies rather than specific acquisitions.

# %%
question = "Summarize the key financial metrics reported in the earnings call related to revenue growth, profitability, cash flow and debt"

# %%
prompt= base_instruction + "\n\n" + "Question:{0}".format(question) + "\n\n" + "Transcript: \n {0}".format(content)

# %%
message = [{"role":"user","content":prompt}]

# %%
question="Which company did asian paints acquired?"

# %%
prompt= base_instruction + "\n\n" + "Question:{0}".format(question) + "\n\n" + "Transcript: \n {0}".format(content)

# %%
message = [{"role":"user","content":prompt}]
