# %%
from transformers import pipeline

pipe = pipeline("token-classification", model="dslim/bert-base-NER")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dslim/bert-base-NER
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
pipe("Delhi is a capital of India")
# Out:
# [{'entity': 'B-LOC',
#   'score': np.float32(0.99969745),
#   'index': 1,
#   'word': 'Delhi',
#   'start': 0,
#   'end': 5},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.99962866),
#   'index': 6,
#   'word': 'India',
#   'start': 22,
#   'end': 27}]

# %%
pipe("USA and Iran are in a war recently")
# Out:
# [{'entity': 'B-LOC',
#   'score': np.float32(0.9998105),
#   'index': 1,
#   'word': 'USA',
#   'start': 0,
#   'end': 3},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.9998499),
#   'index': 3,
#   'word': 'Iran',
#   'start': 8,
#   'end': 12}]
